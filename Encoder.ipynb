# %%
from encoder import *

# %%
a = Encode()
a.main()
# Out:
# --->Inicializando encoder
#
# -->  Tocando Áudio filtrado
# --> Áudio modularizado
# --> Normalizando modularização
#
# --> Executando sinal normalizado
