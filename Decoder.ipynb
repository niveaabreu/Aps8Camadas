# %%
from decoder import *

# %%
a = Decode()
a.main()
# Out:
# --->Inicializando decoder
#
# --->Ouvindo sinal a ser demodularizado
# --->Ouvindo sinal demodularizado
#
# --->Ouvindo sinal demodularizado filtrado
